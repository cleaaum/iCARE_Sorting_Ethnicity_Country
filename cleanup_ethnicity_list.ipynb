# %%
def check_french_canadian(ethnicities_found):
    if "FRENCH" in ethnicities_found:
        ethnicities_found.remove("FRENCH")
    if "CANADIAN" in ethnicities_found:
        ethnicities_found.remove("CANADIAN")
    return ethnicities_found

def check_indo_european(ethnicities_found):
    if "EUROPEAN" in ethnicities_found:
        ethnicities_found.remove("EUROPEAN")
    return ethnicities_found

def check_southern_asian(ethnicities_found):
    if "ASIAN" in ethnicities_found:
        ethnicities_found.remove("ASIAN")
    return ethnicities_found

def check_jewish(ethnicities_found):
    if "RELIGIOUS" in ethnicities_found:
        ethnicities_found.remove("RELIGIOUS")
    return ethnicities_found

def check_latin_american(ethnicities_found):
    if "AMERICAN" in ethnicities_found:
        ethnicities_found.remove("AMERICAN")
    return ethnicities_found

def check_european(ethnicities_found):
    if "EUROPEAN" in ethnicities_found:
        ethnicities_found.remove("EUROPEAN")
    return ethnicities_found

def check_asian(ethnicities_found):
    if "ASIAN" in ethnicities_found:
        ethnicities_found.remove("ASIAN")
    return ethnicities_found

def check_african(ethnicities_found):
    if "AFRICAN" in ethnicities_found:
        ethnicities_found.remove("AFRICAN")
    return ethnicities_found

def check_middle_east(ethnicities_found):
    if "EASTERN_ORIENT" in ethnicities_found:
        ethnicities_found.remove("EASTERN_ORIENT")
    return ethnicities_found

# %%
def remove_redundancies(ethnicities_found):
    ethnicities_found = check_ambiguous_cases(ethnicity, ethnicities_found)
    if "FRENCH_CANADIAN" in ethnicities_found:
        ethnicities_found = check_french_canadian(ethnicities_found_to_set)
    if "HISPANIC" or "LATIN_AMERICA" in ethnicities_found:
        ethnicities_found = check_hispanic_latino(ethnicities_found_to_set, ethnicity)
    if "INDO_EUROPEAN" in ethnicities_found:
        ethnicities_found = check_indo_european(ethnicities_found_to_set)
    if "SOUTHERN_ASIAN" in ethnicities_found:
        ethnicities_found = check_southern_asian(ethnicities_found_to_set)
    if "SOUTH_EASTERN_ASIAN" in ethnicities_found:
        ethnicities_found = check_southern_asian(ethnicities_found_to_set)
    if "JEWISH" in ethnicities_found:
        ethnicities_found = check_jewish(ethnicities_found_to_set)
    if "LATIN_AMERICAN" in ethnicities_found:
        ethnicities_found = check_latin_american(ethnicities_found_to_set)
    if "WESTERN_EUROPEAN" in ethnicities_found:
        ethnicities_found_to_set = check_european(ethnicities_found_to_set)
    if "TAIWANESE" in ethnicities_found:
        ethnicities_found = check_asian(ethnicities_found_to_set)
    if "CHINESE" in ethnicities_found:
        ethnicities_found = check_asian(ethnicities_found_to_set)
    if "THAI" in ethnicities_found:
        ethnicities_found = check_asian(ethnicities_found_to_set)
    if "AFRIKANER" in ethnicities_found:
        ethnicities_found = check_african(ethnicities_found_to_set)
    if "NORTH_AFRICAN" in ethnicities_found:
        ethnicities_found = check_african(ethnicities_found_to_set)
    if "MIDDLE_EASTERN" in ethnicities_found:
        ethnicities_found = check_middle_east(ethnicities_found_to_set)
    return ethnicities_found
